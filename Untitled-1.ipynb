# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf  
import talib ta
import datetime as dt
# %matplotlib inline

# %%
#Tickers and Timeframe

start_date= '20225_01-01'
end_date= '2025_10_01'

# %%
#Data Download

data = yf.download(
    tickers,
    start=start_date,
    end=end_date,
    group_by = 'ticker',
    auto_adjust = True,
    threads = True,
)
